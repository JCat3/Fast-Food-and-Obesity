# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import requests
import json
from census import Census
import gmaps

# %% [markdown]
# **Hypothesis**: The higher number of restaurants in a state will increase the obesity rate
#
# **Null Hypothesis**:  The number of fast food restaurants in a state has no impact on obesity rate in the state
#
# First we will sort the values based on independent variable
#
# Take ⅓ of the values and form a group - highest number of FF
# Next ⅓ form a group - middle number of FF
# Final ⅓ from a group - least number of FF
#
# We will then use an Anova to test our hypothesis.
# Take the 3 datasets and see if they are significantly different from another
# stats.f_oneway(obesitylargestFF, obesity_middleFF, obesity_lowestFF)
#
# If the p < 0.05, then we will reject the null hypothesis.

# %%
# Import the fast food data file 
fastfood_data = pd.read_csv('resources/clean_fast_food.csv')
fastfood_data
# Out:
#       Index               Address  \
# 0         0      800 N Canal Blvd
# 1         2   206 Wears Valley Rd
# 2         3          3652 Parkway
# 3         4  2118 Mt Zion Parkway
# 4         5  9768 Grand River Ave
# ...     ...                   ...
# 9297   9995     3460 Robinhood Rd
# 9298   9996  3069 Kernersville Rd
# 9299   9997         838 S Main St
# 9300   9998   1702 Glendale Dr SW
# 9301   9999       1405 W Broad St
#
#                                           Category           City Country  \
# 0     American Restaurant and Fast Food Restaurant      Thibodaux      US
# 1                             Fast Food Restaurant   Pigeon Forge      US
# 2                                        Fast Food   Pigeon Forge      US
# 3                             Fast Food Restaurant         Morrow      US
# 4                             Fast Food Restaurant        Detroit      US
# ...                                            ...            ...     ...
# 9297                         Fast Food Restaurants  Winston-Salem      US
# 9298                         Fast Food Restaurants  Winston-Salem      US
# 9299                         Fast Food Restaurants   Kernersville      US
# 9300                         Fast Food Restaurants         Wilson      US
# 9301                         Fast Food Restaurants  Elizabethtown      US
#
#        Latitude  Longitude            Name ZipCode           State
# 0     29.814697 -90.814742  SONIC Drive In   70301       Louisiana
# 1     35.803788 -83.580553       Taco Bell   37863       Tennessee
# 2     35.782339 -83.551408          Arby's   37863       Tennessee
# 3     33.562738 -84.321143  Steak 'n Shake   30260         Georgia
# 4     42.368823 -83.138251         Wendy's   48204        Michigan
# ...         ...        ...             ...     ...             ...
# 9297  36.117563 -80.316553       Pizza Hut   27106  North Carolina
# 9298  36.077718 -80.176748       Pizza Hut   27107  North Carolina
# 9299  36.111015 -80.089165       Pizza Hut   27284  North Carolina
# 9300  35.719981 -77.945795       Pizza Hut   27893  North Carolina
# 9301  34.632778 -78.624615       Pizza Hut   28337  North Carolina
#
# [9302 rows x 10 columns]

# %%
obesity_data= pd.read_csv('resources/obesity_data_state_2020.csv')

# %%
fast_food_totals = fastfood_data.groupby("State")[["Index"]].count()
fast_food_totals
# Out:
#                 Index
# State
# Alabama             6
# Alaska             14
# Arizona           295
# Arkansas           90
# California       1111
# Colorado          135
# Connecticut        51
# Delaware           38
# Florida           574
# Georgia           391
# Hawaii             30
# Idaho              50
# Illinois          372
# Indiana           235
# Iowa              108
# Kansas             67
# Kentucky          154
# Louisiana         194
# Maine              23
# Maryland          161
# Massachusetts     195
# Michigan          349
# Minnesota         181
# Mississippi        52
# Missouri          151
# Montana            34
# Nebraska           85
# Nevada            115
# New Hampshire      27
# New Jersey        121
# New Mexico         70
# New York          326
# North Carolina    283
# North Dakota       34
# Ohio              501
# Oklahoma          160
# Oregon            143
# Pennsylvania      360
# Rhode Island       13
# South Carolina    176
# South Dakota       40
# Tennessee         280
# Texas             753
# Utah               58
# Vermont            13
# Virginia          235
# Washington        181
# West Virginia      65
# Wisconsin         174
# Wyoming            28

# %%
fast_food_by_state= pd.merge(fast_food_totals, obesity_data, how = 'right', on = 'State')

#drop any values that do not have data
fast_food_by_state = fast_food_by_state.dropna()

#drop Alabama since it doesn't have enough data for consideration 
fast_food_by_state = fast_food_by_state.drop([0])

# %%
fast_food_by_state
# Out:
#              State   Index  Prevalence        95% CI
# 1           Alaska    14.0        31.9  (29.4, 34.4)
# 2          Arizona   295.0        30.9  (29.5, 32.3)
# 3         Arkansas    90.0        36.4  (34.5, 38.4)
# 4       California  1111.0        30.3  (28.3, 32.2)
# 5         Colorado   135.0        24.2  (23.1, 25.2)
# 6      Connecticut    51.0        29.2  (27.7, 30.8)
# 7         Delaware    38.0        36.5  (34.3, 38.8)
# 9          Florida   574.0        28.4  (26.7, 30.2)
# 10         Georgia   391.0        34.3  (32.5, 36.0)
# 12          Hawaii    30.0        24.5  (23.2, 25.9)
# 13           Idaho    50.0        31.1  (29.4, 32.9)
# 14        Illinois   372.0        32.4  (30.2, 34.6)
# 15         Indiana   235.0        36.8  (35.4, 38.1)
# 16            Iowa   108.0        36.5  (35.3, 37.7)
# 17          Kansas    67.0        35.3  (34.0, 36.5)
# 18        Kentucky   154.0        36.6  (34.6, 38.6)
# 19       Louisiana   194.0        38.1  (36.2, 40.1)
# 20           Maine    23.0        31.0  (29.6, 32.5)
# 21        Maryland   161.0        31.0  (29.8, 32.2)
# 22   Massachusetts   195.0        24.4  (23.0, 25.9)
# 23        Michigan   349.0        35.2  (33.7, 36.7)
# 24       Minnesota   181.0        30.7  (29.8, 31.7)
# 25     Mississippi    52.0        39.7  (38.1, 41.3)
# 26        Missouri   151.0        34.0  (32.7, 35.4)
# 27         Montana    34.0        28.5  (27.1, 30.0)
# 28        Nebraska    85.0        34.0  (32.8, 35.2)
# 29          Nevada   115.0        28.7  (26.2, 31.3)
# 30   New Hampshire    27.0        29.9  (28.2, 31.6)
# 31      New Jersey   121.0        27.7  (26.5, 28.9)
# 32      New Mexico    70.0        30.9  (29.0, 32.8)
# 33        New York   326.0        26.3  (25.3, 27.4)
# 34  North Carolina   283.0        33.6  (32.0, 35.2)
# 35    North Dakota    34.0        33.1  (31.1, 35.1)
# 36            Ohio   501.0        35.5  (34.3, 36.7)
# 37        Oklahoma   160.0        36.4  (34.7, 38.2)
# 38          Oregon   143.0        28.1  (26.6, 29.6)
# 39    Pennsylvania   360.0        31.5  (29.8, 33.2)
# 41    Rhode Island    13.0        30.1  (28.2, 32.1)
# 42  South Carolina   176.0        36.2  (34.2, 38.3)
# 43    South Dakota    40.0        33.2  (30.7, 35.8)
# 44       Tennessee   280.0        35.6  (33.6, 37.6)
# 45           Texas   753.0        35.8  (33.9, 37.7)
# 46            Utah    58.0        28.6  (27.4, 29.7)
# 47         Vermont    13.0        26.3  (24.6, 27.9)
# 48        Virginia   235.0        32.2  (30.8, 33.6)
# 49      Washington   181.0        28.0  (27.0, 29.1)
# 50   West Virginia    65.0        39.1  (37.5, 40.7)
# 51       Wisconsin   174.0        32.3  (30.4, 34.2)
# 52         Wyoming    28.0        30.7  (28.7, 32.7)

# %%
fast_food_by_state.sort_values("Index",axis = 0, ascending = True, inplace = True)

# %%
fast_food_by_state.describe()
# Out:
#              Index  Prevalence
# count    49.000000   49.000000
# mean    189.714286   32.075510
# std     206.697545    3.905313
# min      13.000000   24.200000
# 25%      51.000000   29.200000
# 50%     143.000000   31.900000
# 75%     235.000000   35.500000
# max    1111.000000   39.700000

# %%
fast_food_by_state

fast_food_by_state.columns = ['State',
'Fast Food Count',
'Obesity Rate', 'CI']

# %%
fast_food_by_state
# Out:
#              State  Fast Food Count  Obesity Rate            CI
# 47         Vermont             13.0          26.3  (24.6, 27.9)
# 41    Rhode Island             13.0          30.1  (28.2, 32.1)
# 1           Alaska             14.0          31.9  (29.4, 34.4)
# 20           Maine             23.0          31.0  (29.6, 32.5)
# 30   New Hampshire             27.0          29.9  (28.2, 31.6)
# 52         Wyoming             28.0          30.7  (28.7, 32.7)
# 12          Hawaii             30.0          24.5  (23.2, 25.9)
# 27         Montana             34.0          28.5  (27.1, 30.0)
# 35    North Dakota             34.0          33.1  (31.1, 35.1)
# 7         Delaware             38.0          36.5  (34.3, 38.8)
# 43    South Dakota             40.0          33.2  (30.7, 35.8)
# 13           Idaho             50.0          31.1  (29.4, 32.9)
# 6      Connecticut             51.0          29.2  (27.7, 30.8)
# 25     Mississippi             52.0          39.7  (38.1, 41.3)
# 46            Utah             58.0          28.6  (27.4, 29.7)
# 50   West Virginia             65.0          39.1  (37.5, 40.7)
# 17          Kansas             67.0          35.3  (34.0, 36.5)
# 32      New Mexico             70.0          30.9  (29.0, 32.8)
# 28        Nebraska             85.0          34.0  (32.8, 35.2)
# 3         Arkansas             90.0          36.4  (34.5, 38.4)
# 16            Iowa            108.0          36.5  (35.3, 37.7)
# 29          Nevada            115.0          28.7  (26.2, 31.3)
# 31      New Jersey            121.0          27.7  (26.5, 28.9)
# 5         Colorado            135.0          24.2  (23.1, 25.2)
# 38          Oregon            143.0          28.1  (26.6, 29.6)
# 26        Missouri            151.0          34.0  (32.7, 35.4)
# 18        Kentucky            154.0          36.6  (34.6, 38.6)
# 37        Oklahoma            160.0          36.4  (34.7, 38.2)
# 21        Maryland            161.0          31.0  (29.8, 32.2)
# 51       Wisconsin            174.0          32.3  (30.4, 34.2)
# 42  South Carolina            176.0          36.2  (34.2, 38.3)
# 49      Washington            181.0          28.0  (27.0, 29.1)
# 24       Minnesota            181.0          30.7  (29.8, 31.7)
# 19       Louisiana            194.0          38.1  (36.2, 40.1)
# 22   Massachusetts            195.0          24.4  (23.0, 25.9)
# 15         Indiana            235.0          36.8  (35.4, 38.1)
# 48        Virginia            235.0          32.2  (30.8, 33.6)
# 44       Tennessee            280.0          35.6  (33.6, 37.6)
# 34  North Carolina            283.0          33.6  (32.0, 35.2)
# 2          Arizona            295.0          30.9  (29.5, 32.3)
# 33        New York            326.0          26.3  (25.3, 27.4)
# 23        Michigan            349.0          35.2  (33.7, 36.7)
# 39    Pennsylvania            360.0          31.5  (29.8, 33.2)
# 14        Illinois            372.0          32.4  (30.2, 34.6)
# 10         Georgia            391.0          34.3  (32.5, 36.0)
# 36            Ohio            501.0          35.5  (34.3, 36.7)
# 9          Florida            574.0          28.4  (26.7, 30.2)
# 45           Texas            753.0          35.8  (33.9, 37.7)
# 4       California           1111.0          30.3  (28.3, 32.2)

# %%
#Sort the dataframe
#Then group the dataframe into 3 groups 

group1 = fast_food_by_state[fast_food_by_state["Fast Food Count"] < 66]["Obesity Rate"]
group2 = fast_food_by_state[(fast_food_by_state["Fast Food Count"] > 67) & 
                            (fast_food_by_state["Fast Food Count"] < 181)]["Obesity Rate"]
group3 = fast_food_by_state[fast_food_by_state["Fast Food Count"] > 182]["Obesity Rate"]

# %%
group3
# Out:
# 19    38.1
# 22    24.4
# 15    36.8
# 48    32.2
# 44    35.6
# 34    33.6
# 2     30.9
# 33    26.3
# 23    35.2
# 39    31.5
# 14    32.4
# 10    34.3
# 36    35.5
# 9     28.4
# 45    35.8
# 4     30.3
# Name: Obesity Rate, dtype: float64

# %%
# Run the anova test 

st.f_oneway(group1, group2, group3)
# Out:
# F_onewayResult(statistic=0.3451259121937398, pvalue=0.7100746599651979)
